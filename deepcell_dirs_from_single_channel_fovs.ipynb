# %%
#!/usr/bin/env python
# coding: utf-8

import re
from pathlib import Path
import shutil
from os import remove, rmdir
from sys import argv



def isempty(dir_path):
    # Checks a directory to see if it contains any files
    
    path = Path(dir_path)
    has_next = next(path.iterdir(), None)
    if has_next is None:
        return True
    return False

def create_dir(dir_path):
    # Create an empty directory at dir_path if it doesn't yet exist
    try:
        Path.mkdir(dir_path)
    except FileExistsError:
        if not isempty(input_dir):
            raise Exception('Directory ' +dir_path.name + ' is not empty.')

# %%
rootdir = "/media/austin/DrosophilaMelanogaster/IPI/8plex/data/"

#exp_dirs = [exp for exp in Path(rootdir).iterdir() if exp.is_dir()]

#for exp in exp_dirs:
exp = Path(rootdir, "IPIHNSC065 8plex")
fov_dirs = [fov for fov in Path(exp).iterdir() if fov.is_dir()]

#Create required directory structure for DeepCell
input_dir = Path(exp,"input_data")
create_dir(input_dir)
single_tiff_dir = Path(input_dir, "single_channel_inputs")
create_dir(single_tiff_dir)
mibitiff_dir = Path(input_dir, "mibitiff_inputs")
create_dir(mibitiff_dir)
deepcell_input_dir = Path(input_dir,"deepcell_input")
create_dir(deepcell_input_dir)
deepcell_output_dir = Path(exp, "deepcell_output")
create_dir(deepcell_output_dir)

for f in fov_dirs:

    res = re.match("fov\d+",f.name)[0]
    create_dir(Path(single_tiff_dir,res))

    tiff_dir = Path(single_tiff_dir,res,"TIFs")
    print(tiff_dir)
    create_dir(tiff_dir)

    tiffs = [im_file for im_file in Path(f).iterdir() if (im_file.name.endswith(".tif") or im_file.name.endswith(".tiff"))]

    for tf in tiffs:
        shutil.move(str(tf), str(Path(tiff_dir, tf.name)))

    rmdir(f)
# Out:
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov27/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov46/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov0/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov1/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov10/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov11/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov12/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov13/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov14/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov15/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov16/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov17/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov18/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov19/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov2/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov20/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov21/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov22/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov23/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov24/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov25/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov26/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov28/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov29/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov3/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov30/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov31/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov32/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov33/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov34/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov35/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov36/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov37/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov38/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov39/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov4/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov40/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov41/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov42/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov43/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov44/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov45/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov47/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov48/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov49/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov5/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov50/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov51/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov52/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov53/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov54/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov55/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov56/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov57/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov58/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov59/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov6/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov60/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov61/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov62/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov63/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov64/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov65/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov66/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov67/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov68/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov69/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov7/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov70/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov71/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov72/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov73/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov74/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov75/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov76/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov77/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov78/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov79/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov8/TIFs
# /media/austin/DrosophilaMelanogaster/IPI/8plex/data/IPIHNSC065 8plex/input_data/single_channel_inputs/fov9/TIFs
